# %%
# Q1
import pandas as pd
df = pd.read_excel('flight_price.xlsx')
df.shape
# Out:
# (10683, 11)

# %% [markdown]
#  the dataset contain 10683 rows and 11 columns.

# %%
# Q2
import pandas as pd
df = pd.read_excel('flight_price.xlsx')


df.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'Price'}>]], dtype=object)

# %%
# Q3
import pandas as pd
df = pd.read_excel('flight_price.xlsx')

df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %% [markdown]
# range = min - max =77753,
# min = 1759,
# max = 79512

# %%
# Q4
'Use a major online travel booking site, to compare airline fares against one another.'
import pandas as pd
df = pd.read_excel('flight_price.xlsx')
import matplotlib.pyplot as plt
data1=df['Airline'].unique()
data2=df['Price']
data = [data2, data1]
plt.boxplot(data2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fcdeaf98160>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fcdeaf98610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fcde988d360>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fcdeaf98b50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fcdeaf98df0>],
#  'means': []}

# %%
# Q5
' yes, outliers present in the dataset'
data2=df['Price']
data = [data2, data1]
plt.boxplot(data2)
'above 25000 the all values are an outliers. these outlier effect performance by shifting mean'
# Out:
# 'above 25000 the all values are an outliers. these outlier effect performance by shifting mean'

# %%
# Q6
import pandas as pd
df = pd.read_excel('flight_price.xlsx')


df['Date']=df['Date_of_Journey'].str.split('/').str[0]
df['Month']=df['Date_of_Journey'].str.split('/').str[1]
df['Year']=df['Date_of_Journey'].str.split('/').str[2]
df['Month'].unique()
# summer is the peak travel season, on may analysis, because almost all travel is booked on that season
# Out:
# array(['03', '05', '06', '04'], dtype=object)

# %%
# Q7
##Price dataset to identify any trends in flight prices.
import pandas as pd
df = pd.read_excel('flight_price.xlsx')
import matplotlib.pyplot as plt
data = df['Price']
plt.plot(data)

# %%
# Q8
'''The main determinants that affect the price are:
Product Cost.
The Utility and Demand.
The extent of Competition in the market.
Government and Legal Regulations.
Pricing Objectives.
Marketing Methods used.
'''
# Out:
# 'The main determinants that affect the price are:\nProduct Cost.\nThe Utility and Demand.\nThe extent of Competition in the market.\nGovernment and Legal Regulations.\nPricing Objectives.\nMarketing Methods used.\n'

# %% [markdown]
# ##Google Playstore:

# %%
# Q9
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df.shape
# the dataset contain 10841 rows and 13 columns.
# Out:
# (10841, 13)

# %%
# Q10
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df1 = df.copy()[0:15]
df1['Rating']=df1['Rating'].astype(float)
df1.boxplot(by ='App', column =['Rating'], grid = False)
# Out:
# <AxesSubplot: title={'center': 'Rating'}, xlabel='App'>

# %%
# Q11
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df1 = df.copy()

df1.isnull().sum()
# Dataset has missing values, in rating 1474,in type 1 and current ver 8 ,android ver 3.
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# to handle missing values i use to drop the row 
df1.dropna()
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# Q12
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df1 = df.copy()
df1=df1.drop(df1.index[10472])

df1['Size']=df1['Size'].str.replace('M','000')
df1['Size']=df1['Size'].str.replace('k','')
df1['Size']=df1['Size'].replace('Varies with device',np.nan)
df1['Size']=df1['Size'].astype(float)

d1 = df1['Size']
d2 = df1['Rating']
plt.scatter(d1,d2)
plt.xlabel('app_size')
plt.ylabel('rating')
plt.title('relation_of_app_sizea and rating')
# size is small more rating means large number of people are using the app. 
# large size app have high rating but less number of users.
# Out:
# Text(0.5, 1.0, 'relation_of_app_sizea and rating')

# %%
# Q13
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df1 = df.copy()
df1=df1.drop(df1.index[10472])
df1['price']=df1['Price'].str.split('$').str[1]
df1['price']=df1['price'].astype(float)


   
sns.barplot(data= df1,x= 'price' ,y='Type' )
plt.xlabel('price')
plt.ylabel('type')
plt.title('graph between app type and price')
    
plt.tight_layout()
plt.subplots_adjust(hspace= .3)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /opt/conda/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1559: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a,

# %%
# Q14
# 10 most popular apps.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df1 = df.copy()
df1=df1.drop(df1.index[10472])
df1['Installs']=df1['Installs'].str.replace('+','')
df1['Installs']=df1['Installs'].str.replace(',','')
df1['Installs']=df1['Installs'].astype(float)


dfa = df1.groupby(['Category' ,'App'])['Installs'].sum().reset_index()
dfa = dfa.sort_values('Installs', ascending = False)
apps = ['GAME', 'COMMUNICATION', 'PRODUCTIVITY', 'SOCIAL' ]
sns.set_context("poster")
sns.set_style("darkgrid")

plt.figure(figsize=(40,30))

for i,app in enumerate(apps):
    df2 = dfa[dfa.Category == app]
    df3 = df2.head(10)
    plt.subplot(4,2,i+1)
    sns.barplot(data= df3,x= 'Installs' ,y='App' )
    plt.xlabel('Installation in Millions')
    plt.ylabel('')
    plt.title(app,size = 20)
    
plt.tight_layout()
plt.subplots_adjust(hspace= .3)
plt.show()
# Out:
# /tmp/ipykernel_105/4077600022.py:12: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df1['Installs']=df1['Installs'].str.replace('+','')

# %%
# Q15
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df1 = df.copy()
df1=df1.drop(df1.index[10472])

df1['Installs']=df1['Installs'].str.replace('+','')
df1['Installs']=df1['Installs'].str.replace(',','')
df1['Installs']=df1['Installs'].astype(float)



df_cat_installs = df1.groupby(['Category'])['Installs'].sum().sort_values(ascending = False).reset_index()
df_cat_installs.Installs = df_cat_installs.Installs/1000000000
plt.figure(figsize = (14,10))
sns.set_context("talk")
sns.set_style("darkgrid")

ax = sns.barplot(x = 'Installs' , y = 'Category' , data = df1 )
ax.set_xlabel('No. of Installations in Billions')
ax.set_ylabel('')
ax.set_title("Most Popular Categories in Play Store", size = 20)
# Out:
# /tmp/ipykernel_105/3229968369.py:12: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df1['Installs']=df1['Installs'].str.replace('+','')
# Text(0.5, 1.0, 'Most Popular Categories in Play Store')
